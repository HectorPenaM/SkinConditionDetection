# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2024-03-09 07:59:18.707525: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-09 07:59:18.707625: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-09 07:59:18.767480: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-09 07:59:18.894173: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-09 07:59:20.951705: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def reduce_images(folder_path, target_num_images=400):
    # Obtener la lista de archivos en la carpeta
    file_list = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Verificar si hay más de 400 imágenes
    if len(file_list) <= target_num_images:
        print("El número actual de imágenes es igual o menor a 400. No se requiere reducción.")
        return

    # Calcular cuántas imágenes eliminar
    num_images_to_remove = len(file_list) - target_num_images

    # Eliminar imágenes al azar hasta que quede solo 400
    images_to_remove = random.sample(file_list, num_images_to_remove)
    i=1
    for image_file in images_to_remove:
        image_path = os.path.join(folder_path, image_file)
        os.remove(image_path)
        print(f"{i} Imagen eliminada: {image_file}")
        i = i + 1

    print(f"Se ha reducido el número de imágenes a {target_num_images}.")

# %%
def data_augmentation(folder_path, num_images=150):
    # Obtener la lista de archivos en la carpeta
    file_list = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # Escoger aleatoriamente 150 imágenes
    selected_images = random.sample(file_list, min(num_images, len(file_list)))

    # Configuración para augmentación usando ImageDataGenerator de TensorFlow
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    i=1
    # Iterar sobre las imágenes seleccionadas
    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img = tf.keras.preprocessing.image.load_img(image_path)
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)

        # Crear un generador de imágenes augmentadas
        aug_iter = datagen.flow(img_array, batch_size=1)

        # Obtener la única imagen aumentada rotada
        augmented_img = aug_iter.next()[0].astype(np.uint8)

        # Guardar la imagen aumentada en la misma carpeta
        base_name, ext = os.path.splitext(image_file)
        new_file_name = f"{base_name}_aug{ext}"
        new_file_path = os.path.join(folder_path, new_file_name)
        tf.keras.preprocessing.image.save_img(new_file_path, augmented_img)

        print(f"{i} Data augmentation completada para la imagen: {image_file}")
        i = i+1

# %%
path = "./data/archive/train/sano_pecho"

# %%
reduce_images(path, target_num_images=400)
# Out:
# 1 Imagen eliminada: telangiectasias-17.jpg
# 2 Imagen eliminada: venous-lake-31.jpg
# 3 Imagen eliminada: angiokeratomas-38.jpg
# 4 Imagen eliminada: hemangioma-traumatized-2.jpg
# 5 Imagen eliminada: telangiectasias-56.jpg
# 6 Imagen eliminada: spider-angioma-16.jpg
# 7 Imagen eliminada: av-malformation-1.jpg
# 8 Imagen eliminada: hemangioma-infancy-55.jpg
# 9 Imagen eliminada: venous-malformations-46.jpg
# 10 Imagen eliminada: angiokeratomas-28.jpg
# 11 Imagen eliminada: lymphangioma-circumscriptum-9.jpg
# 12 Imagen eliminada: pyogenic-granuloma-13.jpg
# 13 Imagen eliminada: hemangioma-9.jpg
# 14 Imagen eliminada: hemangioma-234.jpg
# 15 Imagen eliminada: kaposi-sarcoma-29.jpg
# 16 Imagen eliminada: telangiectasias-27.jpg
# 17 Imagen eliminada: pyogenic-granuloma-107.jpg
# 18 Imagen eliminada: av-malformation-4.jpg
# 19 Imagen eliminada: pyogenic-granuloma-41.jpg
# 20 Imagen eliminada: kaposi-sarcoma-3.jpg
# 21 Imagen eliminada: angiokeratomas-16.jpg
# 22 Imagen eliminada: hemangioma-infancy-13.jpg
# 23 Imagen eliminada: telangiectasias-58.jpg
# 24 Imagen eliminada: hemangioma-infancy-38.jpg
# 25 Imagen eliminada: lymphangioma-circumscriptum-8.jpg
# 26 Imagen eliminada: angiokeratomas-19.jpg
# 27 Imagen eliminada: hemangioma-53.jpg
# 28 Imagen eliminada: cherry-angioma-2.jpg
# 29 Imagen eliminada: hemangioma-31.jpg
# 30 Imagen eliminada: pyogenic-granuloma-28.jpg
# 31 Imagen eliminada: venous-malformations-28.jpg
# 32 Imagen eliminada: angiokeratomas-2.jpg
# 33 Imagen eliminada: lymphangioma-circumscriptum-22.jpg
# 34 Imagen eliminada: venous-malformations-7.jpg
# 35 Imagen eliminada: hemangioma-infancy-51.jpg
# 36 Imagen eliminada: venous-malformations-37.jpg
# 37 Imagen eliminada: kaposi-sarcoma-33.jpg
# 38 Imagen eliminada: pyogenic-granuloma-102.jpg
# 39 Imagen eliminada: venous-malformations-12.jpg
# 40 Imagen eliminada: venous-malformations-9.jpg
# 41 Imagen eliminada: telangiectasias-9.jpg
# 42 Imagen eliminada: telangiectasias-39.jpg
# 43 Imagen eliminada: hemangioma-infancy-11.jpg
# 44 Imagen eliminada: angiokeratomas-41.jpg
# 45 Imagen eliminada: pyogenic-granuloma-49.jpg
# 46 Imagen eliminada: pyogenic-granuloma-26.jpg
# 47 Imagen eliminada: hemangioma-10.jpg
# 48 Imagen eliminada: venous-malformations-62.jpg
# 49 Imagen eliminada: pyogenic-granuloma-106.jpg
# 50 Imagen eliminada: kaposi-sarcoma-40.jpg
# 51 Imagen eliminada: telangiectasias-37.jpg
# 52 Imagen eliminada: pyogenic-granuloma-62.jpg
# 53 Imagen eliminada: pyogenic-granuloma-10.jpg
# 54 Imagen eliminada: venous-malformations-11.jpg
# 55 Imagen eliminada: hemangioma-infancy-22.jpg
# 56 Imagen eliminada: lymphangioma-circumscriptum-23.jpg
# 57 Imagen eliminada: hemangioma-41.jpg
# 58 Imagen eliminada: venous-lake-43.jpg
# 59 Imagen eliminada: kaposi-sarcoma-24.jpg
# 60 Imagen eliminada: venous-malformations-67.jpg
# 61 Imagen eliminada: pyogenic-granuloma-94.jpg
# 62 Imagen eliminada: hemangioma-567.jpg
# 63 Imagen eliminada: venous-malformations-30.jpg
# 64 Imagen eliminada: hemangioma-45.jpg
# 65 Imagen eliminada: pyogenic-granuloma-18.jpg
# 66 Imagen eliminada: angiokeratomas-34.jpg
# 67 Imagen eliminada: pyogenic-granuloma-80.jpg
# 68 Imagen eliminada: venous-lake-49.jpg
# 69 Imagen eliminada: hemangioma-16.jpg
# 70 Imagen eliminada: pyogenic-granuloma-55.jpg
# 71 Imagen eliminada: hemangioma-19.jpg
# 72 Imagen eliminada: spider-angioma-9.jpg
# 73 Imagen eliminada: kaposi-sarcoma-37.jpg
# 74 Imagen eliminada: angiokeratomas-12.jpg
# 75 Imagen eliminada: kaposi-sarcoma-12.jpg
# 76 Imagen eliminada: lymphangioma-circumscriptum-14.jpg
# 77 Imagen eliminada: angiokeratomas-31.jpg
# 78 Imagen eliminada: angiokeratomas-37.jpg
# 79 Imagen eliminada: telangiectasias-55.jpg
# 80 Imagen eliminada: venous-malformations-75.jpg
# 81 Imagen eliminada: telangiectasias-23.jpg
# 82 Imagen eliminada: pyogenic-granuloma-40.jpg
# Se ha reducido el número de imágenes a 400.

# %%
data_augmentation(path, num_images=60)
# Out:
# 1 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-21-24.png
# 2 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-36-40.png
# 3 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-45-55.png
# 4 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-18-12.png
# 5 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-23-19.png
# 6 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-52-06.png
# 7 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-02-00.png
# 8 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-43-52.png
# 9 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-09-02.png
# 10 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-17-18.png
# 11 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-21-29.png
# 12 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-57-52.png
# 13 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-48-01.png
# 14 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-49-53.png
# 15 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-03-17.png
# 16 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-06-03.png
# 17 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-50-23.png
# 18 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-42-51.png
# 19 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-43-10.png
# 20 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-17-06.png
# 21 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-03-45.png
# 22 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-16-56.png
# 23 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-37-15.png
# 24 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-49-33.png
# 25 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-42-15.png
# 26 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-40-56.png
# 27 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-18-34.png
# 28 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-47-40.png
# 29 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-28-59.png
# 30 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-58-59.png
# 31 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-18-25.png
# 32 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-51-01.png
# 33 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-00-15.png
# 34 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-08-18.png
# 35 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-34-24.png
# 36 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-40-02.png
# 37 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-15-56.png
# 38 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-43-30.png
# 39 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-21-15.png
# 40 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-37-07.png
# 41 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-18-45.png
# 42 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-22-59.png
# 43 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-54-33.png
# 44 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-26-04.png
# 45 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-53-56.png
# 46 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-11-12.png
# 47 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-16-36.png
# 48 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-24-55.png
# 49 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-46-37.png
# 50 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-50-47.png
# 51 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-33-49.png
# 52 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-16-10.png
# 53 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-21-20.png
# 54 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-48-26.png
# 55 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-36-52.png
# 56 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-45-18.png
# 57 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-52-16.png
# 58 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-16-22.png
# 59 Data augmentation completada para la imagen: Captura desde 2024-03-09 07-06-33.png
# 60 Data augmentation completada para la imagen: Captura desde 2024-03-09 06-48-52.png
